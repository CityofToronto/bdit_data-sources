# %% [markdown]
# # TMC data - preprocessing
#
# Read in raw xslx spreadsheets, format to a proper table, and save to csv.
#
# issue: https://github.com/CityofToronto/bdit_data-sources/issues/377

# %%
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd 
# import configparser
# from psycopg2 import connect
# import psycopg2.sql as pg
# import pandas.io.sql as pandasql
import numpy as np 
import datetime
# import datetime as dt
# import rick

import importlib
import matplotlib.ticker as ticker
import matplotlib.font_manager as font_manager
import matplotlib.dates as mdates
from matplotlib.lines import Line2D # for legend

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %% [markdown]
# # Config

# %%
# # JUPYTERHUB
# CONFIG=configparser.ConfigParser()
# CONFIG.read('/home/cnangini/db.cfg')
# dbset=CONFIG['DBSETTINGS']
# con=connect(**dbset)
# i=0

# %% [markdown]
# # Palette

# %% [markdown]
# # Dictionaries

# %% [markdown]
# # Functions

# %% [markdown]
# ## Line Chart

# %%
def get_ypos(df, sett):
    '''Output y-position of labels based on max of all data.'''
    
    label_ypos=(int(df[list(df)[1:]].max().max() + 
                        0.025*(df[list(df)[1:]].max().max())))
    
    return label_ypos

# %%
def get_install_dates(segment):
    '''Returns limits of installation date for given segment.
    '''
    
    query = '''SELECT segment, 
        lower(install) as min_date, 
        upper(install) as max_date
        FROM rapidto.miovision_segment_info_split
        WHERE segment='{segment}'
        GROUP BY segment, lower(install),upper(install)
        ORDER BY lower(install);
        '''.format(segment=segment)
    
    with con:
        df = pandasql.read_sql(query, con)
        
          
    lims=[[pd.to_datetime(df['min_date'].iloc[0]),
         pd.to_datetime(df['max_date'].iloc[0])]]
    
    return lims

# %%
def find_weekend_indices(df):
    xcol=list(df)[0]
    datetime_array=df[xcol]
    
    s = []
    for i in range(len(datetime_array) - 1):
        if datetime_array[i].weekday() >= 5:
            s.append([df[xcol][i], df[xcol][i + 1]])
#             s2.append(df[xcol][i + 1])  

    return s

# %%
def my_linechart(df_orig, sett):
    """Creates a line chart. x axis must be modified manually        
    Parameters
    -----------
    df : pandas dataframe
        Data for the line chart.
    sett: settings object containing styling and annotation parameters      
    
    Optional params:
    
    
    Returns 
    --------
    fig
        Matplotlib fig object
    ax 
        Matplotlib ax object
 
    """ 
    df=df_orig.copy()
    
    # -------------------------
    # Styling params
    lw=2 if 'lw' not in sett else sett['lw']
    fontsize=9 if 'fontsize' not in sett else sett['fontsize']
    
    # -------------------------
    # Setup the figure
    fig, ax =plt.subplots(1)
#     fig.set_size_inches(9.6, 2.3)
    fig.set_size_inches(18, 5)   #.set_size_inches(18, 10)
    ax = plt.gca()
    ax.tick_params(width=1, length=2)
    ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}')) # format y-axis values with comma
    mpl.rcParams['axes.linewidth'] = 0.3 # set the value globally
    
#     plt.grid()
    #plt.grid(b=True, which='both', color='0.5', linestyle='-')
    plt.grid(b=True, which='major', color='gray', linestyle='-')
    plt.grid(b=True, which='minor', color='#D3D3D3', linestyle='--')

    
    # -------------------------
    # Define line-number-dependent params
    num_lines=len(sett['data'].keys())
    
    col_names=['xcol']
    ymax_array=[]
    for n in range(num_lines):
        col_names.append('ycol_' + str(n))
        ymax_array.append(df.iloc[:,n+1].max())
        
    

    df.columns=col_names
    ymax=np.max(ymax_array)

    
    #-------------------------
    # y-axis
    ymax = ymax + ymax*.1
    if 'ymin' in sett:
        ymin=sett['ymin']
    else:
        ymin=0
          
    delta = (ymax - ymin)/4
    i = 0
    while True:
        delta /= 10
        i += 1
        if delta < 10:
            break
    if 'yinc' in sett:
        yinc=sett['yinc']
    else:
        yinc = int(round(delta+1)*pow(10,i))
                   
    plt.ylim(top=ymax, bottom=ymin)
    if 'ylab' in sett:
        align= 'center' if 'align' not in sett else sett['align']
        plt.ylabel(sett['ylab'], fontsize=fontsize)
    
    # Format x-axis ticks
    if 'major_loc' in sett: # x-values are dates
        if 'minor_loc' in sett:
            ax.xaxis.set_minor_locator(sett['minor_loc'])

    # --------------------------
    # Plot data
    for n in range(num_lines):
        ax.plot(df['xcol'], df['ycol_' + str(n)], linewidth=lw, 
                color = sett['data'][n]['lc'], linestyle=sett['data'][n]['ls'])

    # --------------------------
    # Legend
    if 'legend_label' in sett:
        if sett['legend_label']==True:
            legend_pos='upper left' if 'legend_pos' not in sett else sett['legend_pos']
            ncol=len(df.columns) if 'legend_ncol' not in sett else sett['legend_ncol']

            leg_array=[]
            custom_lines=[]
            for n in range(num_lines):
                leg_array.append(sett['data'][n]['leg'])
                custom_lines.append(
                    Line2D([0], [0], color=sett['data'][n]['lc'], lw=lw,
                          linestyle=sett['data'][n]['ls'])
                )        


            leg_font=fontsize if 'legend_font' not in sett else sett['legend_font']
            ax.legend(custom_lines, leg_array, loc=legend_pos, 
                      prop={"size": leg_font},
                      ncol=ncol, handlelength=3
                     )
    
    # --------------------------
    # Shaded areas
    if 'shaded' in sett:
        num_a=len(sett['shaded'].keys())
        
        for area in range(num_a):
            idx=sett['shaded'][area]['lims']
            facecolour=sett['shaded'][area]['c']
            zorder=0 if 'zorder' not in sett['shaded'][area] else (
                sett['shaded'][area]['zorder'])
            alpha=1 if 'alpha' not in sett['shaded'][area] else (
                sett['shaded'][area]['alpha'])
            
            # Shaded area left and right bds
            for i in range(len(idx)):
                bd1=idx[i][0]
                bd2=idx[i][1]
                
                ax.axvspan(bd1, bd2, 
                       facecolor=facecolour, edgecolor='none', alpha=alpha,
                          zorder=zorder)
            
            # Shaded area label
            if 'label' in sett['shaded'][area]:
                trans = ax.get_xaxis_transform()
        
                plt.text(                    
                    sett['shaded'][area]['label']['x'], # x posn of label
                    sett['shaded'][area]['label']['y'], # y posn of label
                    sett['shaded'][area]['label']['text'], 
                    color = sett['shaded'][area]['label']['colour'], 
                    fontsize=sett['shaded'][area]['label']['fontsize']
                )

# %% [markdown]
# # I Define file list
# Output of `ls` in data dir.

# %%
data_dir='~/Documents/PROJECTS/BDITTO/WYS/VALIDATION/PREPROCESSED/'

# %%
fname_list=[
    '2020-04-27_MAIN SOUTHBOUND NORTH OF SWANWICK.xlsx', 
    '2020-05-07_GATEWAY SOUTH EASTBOUND EAST OF DON MILLS.xlsx',
    '2020-04-28_NEWPORT EASTBOUND WEST OF AUGUST.xlsx', 
    '2020-05-11_UNDERHILL NORTHBOUND SOUTH OF MONARCHWOOD.xlsx',
    '2020-04-29_PHARMACY NORTHBOUND SOUTH OF DENTON.xlsx', 
    '2020-05-12_STRATFORD WESTBOUND WEST OF MILDENHALL.xlsx',
    '2020-04-30_DENTON WESTBOUND EAST OF BYNG.xlsx',
    '2020-05-13_BYNG NORTHBOUND SOUTH OF DENTON.xlsx',
    '2020-05-04_GRENOBLE WESTBOUND WEST OF LEEWARD GLENWAY EAST.xlsx', 
    '2020-05-14_PHARMACY SOUTHBOUND NORTH OF DENTON.xlsx',
    '2020-05-05_JONES SOUTHBOUND SOUTH OF HUNTER.xlsx',
    '2020-05-19_BELSIZE WESTBOUND EAST OF CHESTON.xlsx',
    '2020-05-06_JONES SOUTHBOUND SOUTH OF HARCOURT.xlsx', 
    '2020-05-20_CHESTON SOUTHBOUND NORTH OF BELSIZE.xlsx'
]

# %% [markdown]
# # II Loop through all files and output data in one dataframe
# Output dataframe defined as `columns=['datetime_bin', 'location', 'class_type','count']`
# where:
#
# - `datetime_bin` taken from `Time` column in each file
# - `location` taken from top of each file `Location:	Main Street Southbound North of Swanwick Avenue`
# - `class_type = [Cars,Trucks,Bicycles,Transit,Pedestrians,Other]` as read from the column headers in each file
# - `count` taken from the values in each `class_type` in the file

# %%
from datetime import timedelta

def read_xls():
    '''Read set of xlsx files, extract the relevant data, and format into a proper dataframe.'''
    
    # Set up output df
    df=pd.DataFrame(columns=['datetime_bin', 'location', 'class_type','count'])
    
    # Initialize arrays that will store values from each file
    timebin_array=[]
    location_array=[]
    classtype_array=[]
    count_array=[]
    
    # Loop through all files in fname_list, extract data from each column,
    # and append to one big long array that will then be stored in the 
    # final return df.
    idx=1
    for fname in fname_list: # start with one file only
        print('File ' + str(idx) + ': ' + fname)
        # 1. Get data from spreadsheet and store in this_df
        this_df=pd.read_excel(data_dir + fname, skiprows=9).dropna().reset_index(drop=True)
        class_types=list(this_df)[1:] # class types in spreadsheet
        n_classes=len(list(this_df)[1:]) # number of classes in spreadsheet
        
        # Convert all times to 24 hour notation in section after this_df['Time']=='Time'
        delta=datetime.timedelta(hours = 12)

        this_df.loc[this_df.index.values > this_df.loc[this_df['Time']=='Time'].index.values[0], 'Time']=(
            this_df.loc[this_df.index.values > 
                        this_df.loc[this_df['Time']=='Time'].index.values[0], 'Time'].apply(lambda x: (
            datetime.datetime.combine(datetime.date(1,1,1), x) + delta).time()))
        
        
        this_loc=list(pd.read_excel(data_dir + fname, skiprows=3))[1]
        obs_date=list(pd.read_excel(data_dir + fname, skiprows=5))[1]
        
        print(this_loc)
        print(obs_date.date())
        print('')
        idx=idx+1
        
        # drop second column headers
        this_df = this_df[this_df.Time != 'Time']
        
        # 2. Extract column values of this_df for each class_type
        # and append to one long array for each 
        for class_type in class_types:
            location_array = location_array + [this_loc for i in range(len(list(this_df['Time'].values)))]
            classtype_array = classtype_array + [class_type for i in range(len(list(this_df['Time'].values)))]
            timebin_array=timebin_array + list(this_df['Time'].values)
            count_array=count_array + list(this_df[class_type].values)
            print('len count_array: ' + str(len(count_array)))
            
        print('')
            
    # 3. Add all the arrays to the return df
    df['datetime_bin']=timebin_array
    df['location']=location_array
    df['class_type']=classtype_array
    df['count']=count_array
    
  
        
    return df

# %%
df_all=read_xls()
# Out:
# File 1: 2020-04-27_MAIN SOUTHBOUND NORTH OF SWANWICK.xlsx
# Main Street Southbound North of Swanwick Avenue
# 2020-04-27
#
# len count_array: 48
# len count_array: 96
# len count_array: 144
# len count_array: 192
# len count_array: 240
# len count_array: 288
#
# File 2: 2020-05-07_GATEWAY SOUTH EASTBOUND EAST OF DON MILLS.xlsx
# Gateway Boulevard South Eastbound East of Don Mills Road
# 2020-05-07
#
# len count_array: 371
# len count_array: 454
# len count_array: 537
# len count_array: 620
# len count_array: 703
# len count_array: 786
#
# File 3: 2020-04-28_NEWPORT EASTBOUND WEST OF AUGUST.xlsx
# Newport Avenue Eastbound West of August Avenue
# 2020-04-28
#
# len count_array: 834
# len count_array: 882
# len count_array: 930
# len count_array: 978
# len count_array: 1026
# len count_array: 1074
#
# File 4: 2020-05-11_UNDERHILL NORTHBOUND SOUTH OF MONARCHWOOD.xlsx
# Underhill Drive Northbound South of Monarchwood Crescent
# 2020-05-11
#
# len count_array: 1148
# len count_array: 1222
# len count_array: 1296
# len count_array: 1370
# len count_array: 1444
# len count_array: 1518
#
# File 5: 2020-04-29_PHARMACY NORTHBOUND SOUTH OF DENTON.xlsx
# Pharmacy Avenue Northbound South of Denton Avenue
# 2020-04-29
#
# len count_array: 1566
# len count_array: 1614
# len count_array: 1662
# len count_array: 1710
# len count_array: 1758
# len count_array: 1806
#
# File 6: 2020-05-12_STRATFORD WESTBOUND WEST OF MILDENHALL.xlsx
# Stratford Crescent Westbound West of Mildenhall Drive
# 2020-05-12
#
# len count_array: 1890
# len count_array: 1974
# len count_array: 2058
# len count_array: 2142
# len count_array: 2226
# len count_array: 2310
#
# File 7: 2020-04-30_DENTON WESTBOUND EAST OF BYNG.xlsx
# Denton Avenue Westbound East of Byng Avenue
# 2020-04-30
#
# len count_array: 2358
# len count_array: 2406
# len count_array: 2454
# len count_array: 2502
# len count_array: 2550
# len count_array: 2598
#
# File 8: 2020-05-13_BYNG NORTHBOUND SOUTH OF DENTON.xlsx
# Byng Avenue Northbound South of Denton Avenue
# 2020-05-13
#
# len count_array: 2682
# len count_array: 2766
# len count_array: 2850
# len count_array: 2934
# len count_array: 3018
# len count_array: 3102
#
# File 9: 2020-05-04_GRENOBLE WESTBOUND WEST OF LEEWARD GLENWAY EAST.xlsx
# Grenoble Drive Westbound West of Leeward Glenway East
# 2020-05-04
#
# len count_array: 3149
# len count_array: 3196
# len count_array: 3243
# len count_array: 3290
# len count_array: 3337
# len count_array: 3384
#
# File 10: 2020-05-14_PHARMACY SOUTHBOUND NORTH OF DENTON.xlsx
# Pharmacy Avenue Southbound North of Denton Avenue
# 2020-05-14
#
# len count_array: 3468
# len count_array: 3552
# len count_array: 3636
# len count_array: 3720
# len count_array: 3804
# len count_array: 3888
#
# File 11: 2020-05-05_JONES SOUTHBOUND SOUTH OF HUNTER.xlsx
# Jones Avenue Southbound South of Hunter Street
# 2020-05-05
#
# len count_array: 3936
# len count_array: 3984
# len count_array: 4032
# len count_array: 4080
# len count_array: 4128
# len count_array: 4176
#
# File 12: 2020-05-19_BELSIZE WESTBOUND EAST OF CHESTON.xlsx
# Belsize Drive Westbound East of Cheston Road
# 2020-05-19
#
# len count_array: 4260
# len count_array: 4344
# len count_array: 4428
# len count_array: 4512
# len count_array: 4596
# len count_array: 4680
#
# File 13: 2020-05-06_JONES SOUTHBOUND SOUTH OF HARCOURT.xlsx
# Jones Avenue Southbound South of Harcourt Avenue
# 2020-05-06
#
# len count_array: 4728
# len count_array: 4776
# len count_array: 4824
# len count_array: 4872
# len count_array: 4920
# len count_array: 4968
#
# File 14: 2020-05-20_CHESTON SOUTHBOUND NORTH OF BELSIZE.xlsx
# Cheston Road Southbound North of Belsize Drive
# 2020-05-20
#
# len count_array: 5052
# len count_array: 5136
# len count_array: 5220
# len count_array: 5304
# len count_array: 5388
# len count_array: 5472

# %%
288*14
# Out:
# 4032

# %%
print(df_all.shape)
df_all
# Out:
# (5472, 4)
#      datetime_bin                                         location class_type  \
# 0        10:00:00  Main Street Southbound North of Swanwick Avenue       Cars
# 1        10:05:00  Main Street Southbound North of Swanwick Avenue       Cars
# 2        10:10:00  Main Street Southbound North of Swanwick Avenue       Cars
# 3        10:15:00  Main Street Southbound North of Swanwick Avenue       Cars
# 4        10:20:00  Main Street Southbound North of Swanwick Avenue       Cars
# 5        10:25:00  Main Street Southbound North of Swanwick Avenue       Cars
# 6        10:30:00  Main Street Southbound North of Swanwick Avenue       Cars
# 7        10:35:00  Main Street Southbound North of Swanwick Avenue       Cars
# 8        10:40:00  Main Street Southbound North of Swanwick Avenue       Cars
# 9        10:45:00  Main Street Southbound North of Swanwick Avenue       Cars
# 10       10:50:00  Main Street Southbound North of Swanwick Avenue       Cars
# 11       10:55:00  Main Street Southbound North of Swanwick Avenue       Cars
# 12       11:00:00  Main Street Southbound North of Swanwick Avenue       Cars
# 13       11:05:00  Main Street Southbound North of Swanwick Avenue       Cars
# 14       11:10:00  Main Street Southbound North of Swanwick Avenue       Cars
# 15       11:15:00  Main Street Southbound North of Swanwick Avenue       Cars
# 16       11:20:00  Main Street Southbound North of Swanwick Avenue       Cars
# 17       11:25:00  Main Street Southbound North of Swanwick Avenue       Cars
# 18       11:30:00  Main Street Southbound North of Swanwick Avenue       Cars
# 19       11:35:00  Main Street Southbound North of Swanwick Avenue       Cars
# 20       11:40:00  Main Street Southbound North of Swanwick Avenue       Cars
# 21       11:45:00  Main Street Southbound North of Swanwick Avenue       Cars
# 22       11:50:00  Main Street Southbound North of Swanwick Avenue       Cars
# 23       11:55:00  Main Street Southbound North of Swanwick Avenue       Cars
# 24       16:00:00  Main Street Southbound North of Swanwick Avenue       Cars
# 25       16:05:00  Main Street Southbound North of Swanwick Avenue       Cars
# 26       16:10:00  Main Street Southbound North of Swanwick Avenue       Cars
# 27       16:15:00  Main Street Southbound North of Swanwick Avenue       Cars
# 28       16:20:00  Main Street Southbound North of Swanwick Avenue       Cars
# 29       16:25:00  Main Street Southbound North of Swanwick Avenue       Cars
# ...           ...                                              ...        ...
# 5442     15:30:00   Cheston Road Southbound North of Belsize Drive      Other
# 5443     15:35:00   Cheston Road Southbound North of Belsize Drive      Other
# 5444     15:40:00   Cheston Road Southbound North of Belsize Drive      Other
# 5445     15:45:00   Cheston Road Southbound North of Belsize Drive      Other
# 5446     15:50:00   Cheston Road Southbound North of Belsize Drive      Other
# 5447     15:55:00   Cheston Road Southbound North of Belsize Drive      Other
# 5448     16:00:00   Cheston Road Southbound North of Belsize Drive      Other
# 5449     16:05:00   Cheston Road Southbound North of Belsize Drive      Other
# 5450     16:10:00   Cheston Road Southbound North of Belsize Drive      Other
# 5451     16:15:00   Cheston Road Southbound North of Belsize Drive      Other
# 5452     16:20:00   Cheston Road Southbound North of Belsize Drive      Other
# 5453     16:25:00   Cheston Road Southbound North of Belsize Drive      Other
# 5454     16:30:00   Cheston Road Southbound North of Belsize Drive      Other
# 5455     16:35:00   Cheston Road Southbound North of Belsize Drive      Other
# 5456     16:40:00   Cheston Road Southbound North of Belsize Drive      Other
# 5457     16:45:00   Cheston Road Southbound North of Belsize Drive      Other
# 5458     16:50:00   Cheston Road Southbound North of Belsize Drive      Other
# 5459     16:55:00   Cheston Road Southbound North of Belsize Drive      Other
# 5460     17:00:00   Cheston Road Southbound North of Belsize Drive      Other
# 5461     17:05:00   Cheston Road Southbound North of Belsize Drive      Other
# 5462     17:10:00   Cheston Road Southbound North of Belsize Drive      Other
# 5463     17:15:00   Cheston Road Southbound North of Belsize Drive      Other
# 5464     17:20:00   Cheston Road Southbound North of Belsize Drive      Other
# 5465     17:25:00   Cheston Road Southbound North of Belsize Drive      Other
# 5466     17:30:00   Cheston Road Southbound North of Belsize Drive      Other
# 5467     17:35:00   Cheston Road Southbound North of Belsize Drive      Other
# 5468     17:40:00   Cheston Road Southbound North of Belsize Drive      Other
# 5469     17:45:00   Cheston Road Southbound North of Belsize Drive      Other
# 5470     17:50:00   Cheston Road Southbound North of Belsize Drive      Other
# 5471     17:55:00   Cheston Road Southbound North of Belsize Drive      Other
#
#       count
# 0         6
# 1         8
# 2        14
# 3         8
# 4        15
# 5        13
# 6        16
# 7        15
# 8        23
# 9        13
# 10       13
# 11       14
# 12       10
# 13        7
# 14       15
# 15       16
# 16       10
# 17       20
# 18       12
# 19       21
# 20       16
# 21       21
# 22       14
# 23       18
# 24       16
# 25       18
# 26       15
# 27        8
# 28       15
# 29       12
# ...     ...
# 5442      0
# 5443      0
# 5444      0
# 5445      0
# 5446      0
# 5447      0
# 5448      0
# 5449      0
# 5450      0
# 5451      0
# 5452      0
# 5453      0
# 5454      0
# 5455      0
# 5456      0
# 5457      0
# 5458      0
# 5459      0
# 5460      0
# 5461      0
# 5462      0
# 5463      0
# 5464      0
# 5465      0
# 5466      0
# 5467      0
# 5468      0
# 5469      0
# 5470      0
# 5471      0
#
# [5472 rows x 4 columns]

# %%
# sort by datetime_bin
df_all.sort_values('datetime_bin').reset_index(drop=True)
# Out:
#      datetime_bin                                           location  \
# 0        08:00:00  Underhill Drive Northbound South of Monarchwoo...
# 1        08:00:00  Stratford Crescent Westbound West of Mildenhal...
# 2        08:00:00  Underhill Drive Northbound South of Monarchwoo...
# 3        08:00:00  Gateway Boulevard South Eastbound East of Don ...
# 4        08:00:00      Byng Avenue Northbound South of Denton Avenue
# 5        08:00:00  Stratford Crescent Westbound West of Mildenhal...
# 6        08:00:00  Pharmacy Avenue Southbound North of Denton Avenue
# 7        08:00:00     Cheston Road Southbound North of Belsize Drive
# 8        08:00:00      Byng Avenue Northbound South of Denton Avenue
# 9        08:00:00     Cheston Road Southbound North of Belsize Drive
# 10       08:00:00  Stratford Crescent Westbound West of Mildenhal...
# 11       08:00:00       Belsize Drive Westbound East of Cheston Road
# 12       08:00:00       Belsize Drive Westbound East of Cheston Road
# 13       08:00:00       Belsize Drive Westbound East of Cheston Road
# 14       08:00:00       Belsize Drive Westbound East of Cheston Road
# 15       08:00:00     Cheston Road Southbound North of Belsize Drive
# 16       08:00:00      Byng Avenue Northbound South of Denton Avenue
# 17       08:00:00  Stratford Crescent Westbound West of Mildenhal...
# 18       08:00:00     Cheston Road Southbound North of Belsize Drive
# 19       08:00:00     Cheston Road Southbound North of Belsize Drive
# 20       08:00:00  Pharmacy Avenue Southbound North of Denton Avenue
# 21       08:00:00  Pharmacy Avenue Southbound North of Denton Avenue
# 22       08:00:00  Pharmacy Avenue Southbound North of Denton Avenue
# 23       08:00:00  Gateway Boulevard South Eastbound East of Don ...
# 24       08:00:00      Byng Avenue Northbound South of Denton Avenue
# 25       08:00:00  Gateway Boulevard South Eastbound East of Don ...
# 26       08:00:00  Gateway Boulevard South Eastbound East of Don ...
# 27       08:00:00  Stratford Crescent Westbound West of Mildenhal...
# 28       08:00:00  Gateway Boulevard South Eastbound East of Don ...
# 29       08:00:00  Underhill Drive Northbound South of Monarchwoo...
# ...           ...                                                ...
# 5442     17:55:00  Stratford Crescent Westbound West of Mildenhal...
# 5443     17:55:00  Pharmacy Avenue Southbound North of Denton Avenue
# 5444     17:55:00     Newport Avenue Eastbound West of August Avenue
# 5445     17:55:00  Grenoble Drive Westbound West of Leeward Glenw...
# 5446     17:55:00  Gateway Boulevard South Eastbound East of Don ...
# 5447     17:55:00     Newport Avenue Eastbound West of August Avenue
# 5448     17:55:00  Underhill Drive Northbound South of Monarchwoo...
# 5449     17:55:00    Main Street Southbound North of Swanwick Avenue
# 5450     17:55:00        Denton Avenue Westbound East of Byng Avenue
# 5451     17:55:00       Belsize Drive Westbound East of Cheston Road
# 5452     17:55:00        Denton Avenue Westbound East of Byng Avenue
# 5453     17:55:00     Jones Avenue Southbound South of Hunter Street
# 5454     17:55:00  Gateway Boulevard South Eastbound East of Don ...
# 5455     17:55:00  Pharmacy Avenue Southbound North of Denton Avenue
# 5456     17:55:00  Stratford Crescent Westbound West of Mildenhal...
# 5457     17:55:00  Underhill Drive Northbound South of Monarchwoo...
# 5458     17:55:00        Denton Avenue Westbound East of Byng Avenue
# 5459     17:55:00     Jones Avenue Southbound South of Hunter Street
# 5460     17:55:00   Jones Avenue Southbound South of Harcourt Avenue
# 5461     17:55:00     Cheston Road Southbound North of Belsize Drive
# 5462     17:55:00       Belsize Drive Westbound East of Cheston Road
# 5463     17:55:00    Main Street Southbound North of Swanwick Avenue
# 5464     17:55:00  Gateway Boulevard South Eastbound East of Don ...
# 5465     17:55:00        Denton Avenue Westbound East of Byng Avenue
# 5466     17:55:00  Stratford Crescent Westbound West of Mildenhal...
# 5467     17:55:00     Jones Avenue Southbound South of Hunter Street
# 5468     17:55:00   Jones Avenue Southbound South of Harcourt Avenue
# 5469     17:55:00     Cheston Road Southbound North of Belsize Drive
# 5470     17:55:00      Byng Avenue Northbound South of Denton Avenue
# 5471     17:55:00     Cheston Road Southbound North of Belsize Drive
#
#        class_type  count
# 0         Transit      1
# 1        Bicycles      0
# 2        Bicycles      0
# 3           Other      0
# 4        Bicycles      0
# 5          Trucks      0
# 6          Trucks      0
# 7          Trucks      0
# 8         Transit      0
# 9            Cars      0
# 10           Cars      0
# 11           Cars      0
# 12         Trucks      0
# 13       Bicycles      0
# 14        Transit      0
# 15          Other      0
# 16    Pedestrians      0
# 17        Transit      0
# 18    Pedestrians      0
# 19        Transit      0
# 20    Pedestrians      0
# 21        Transit      1
# 22          Other      0
# 23       Bicycles      0
# 24           Cars      0
# 25    Pedestrians      0
# 26           Cars      5
# 27          Other      0
# 28        Transit      2
# 29           Cars      4
# ...           ...    ...
# 5442        Other      0
# 5443  Pedestrians      0
# 5444     Bicycles      0
# 5445      Transit      1
# 5446      Transit      2
# 5447        Other      0
# 5448         Cars     25
# 5449         Cars     12
# 5450        Other      0
# 5451      Transit      0
# 5452  Pedestrians      0
# 5453     Bicycles      1
# 5454  Pedestrians      0
# 5455     Bicycles      0
# 5456       Trucks      0
# 5457       Trucks      0
# 5458      Transit      0
# 5459       Trucks      0
# 5460        Other      0
# 5461      Transit      0
# 5462  Pedestrians      0
# 5463       Trucks      0
# 5464        Other      0
# 5465     Bicycles      0
# 5466     Bicycles      0
# 5467         Cars     11
# 5468  Pedestrians      0
# 5469  Pedestrians      0
# 5470  Pedestrians      1
# 5471        Other      0
#
# [5472 rows x 4 columns]

# %% [markdown]
# # III Check size
#
# Size of final dataframe should be number of files * (number of data lines in each file  * num class types)

# %%
len(fname_list) * ((24 + 24) * 6)
# Out:
# 4032

# %%
print(df_all.shape)
# Out:
# (5472, 4)

# %% [markdown]
# # IV Save to csv

# %%
savename='kertcher_all.csv'
df_all.sort_values('datetime_bin').reset_index(drop=True).to_csv(data_dir + savename, index=False)
